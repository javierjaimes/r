# %%
library(readr)
library(ggplot2)
library(dplyr)
library(magrittr)

# %% [markdown]
# # Class 02
# ## Wed 05, 2024
#
# 1. Starting configuring R Markdown
# 2. Resource: Book R Markdown Cookbook

# %%
iris <- read_csv("data/iris.data")
names(iris) <- c("sepal.length", "sepal.width", "petal.length", "petal.width", "class")
# Out:
# Rows: 149 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): Iris-setosa
# dbl (4): 5.1, 3.5, 1.4, 0.2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Dataframes Manipulation with R

# %%
# Print the dataframe struct
str(iris)
# Out:
# spc_tbl_ [149 × 5] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ sepal.length: num [1:149] 4.9 4.7 4.6 5 5.4 4.6 5 4.4 4.9 5.4 ...
#  $ sepal.width : num [1:149] 3 3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 ...
#  $ petal.length: num [1:149] 1.4 1.3 1.5 1.4 1.7 1.4 1.5 1.4 1.5 1.5 ...
#  $ petal.width : num [1:149] 0.2 0.2 0.2 0.2 0.4 0.3 0.2 0.2 0.1 0.2 ...
#  $ class       : chr [1:149] "Iris-setosa" "Iris-setosa" "Iris-setosa" "Iris-setosa" ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   `5.1` = col_double(),
#   ..   `3.5` = col_double(),
#   ..   `1.4` = col_double(),
#   ..   `0.2` = col_double(),
#   ..   `Iris-setosa` = col_character()
#   .. )
#  - attr(*, "problems")=<externalptr>

# %%
# display the head
head(iris)
# Out:
#   sepal length sepal width petal length petal width class
# 1 4.9          3.0         1.4          0.2         Iris-setosa
# 2 4.7          3.2         1.3          0.2         Iris-setosa
# 3 4.6          3.1         1.5          0.2         Iris-setosa
# 4 5.0          3.6         1.4          0.2         Iris-setosa
# 5 5.4          3.9         1.7          0.4         Iris-setosa
# 6 4.6          3.4         1.4          0.3         Iris-setosa

# %%
# filtering data
iris_setosa <- filter(iris, class == "Iris-setosa")
iris_setosa
# Out:
#    sepal length sepal width petal length petal width class
# 1  4.9          3.0         1.4          0.2         Iris-setosa
# 2  4.7          3.2         1.3          0.2         Iris-setosa
# 3  4.6          3.1         1.5          0.2         Iris-setosa
# 4  5.0          3.6         1.4          0.2         Iris-setosa
# 5  5.4          3.9         1.7          0.4         Iris-setosa
# 6  4.6          3.4         1.4          0.3         Iris-setosa
# 7  5.0          3.4         1.5          0.2         Iris-setosa
# 8  4.4          2.9         1.4          0.2         Iris-setosa
# 9  4.9          3.1         1.5          0.1         Iris-setosa
# 10 5.4          3.7         1.5          0.2         Iris-setosa
# 11 4.8          3.4         1.6          0.2         Iris-setosa
# 12 4.8          3.0         1.4          0.1         Iris-setosa
# 13 4.3          3.0         1.1          0.1         Iris-setosa
# 14 5.8          4.0         1.2          0.2         Iris-setosa
# ...

# %%
# Dataframe column names
names(iris)
# Out:
# [1] "sepal length" "sepal width"  "petal length" "petal width"  "class"

# %%
# Dataframe column values
unique(iris$class)
# Out:
# [1] "Iris-setosa"     "Iris-versicolor" "Iris-virginica"

# %%
iris_setosa_median <- iris %>% filter(class == "Iris-setosa") %>% filter(sepal.length>0.1)
iris_setosa_median
# Out:
#    sepal.length sepal.width petal.length petal.width class
# 1  4.9          3.0         1.4          0.2         Iris-setosa
# 2  4.7          3.2         1.3          0.2         Iris-setosa
# 3  4.6          3.1         1.5          0.2         Iris-setosa
# 4  5.0          3.6         1.4          0.2         Iris-setosa
# 5  5.4          3.9         1.7          0.4         Iris-setosa
# 6  4.6          3.4         1.4          0.3         Iris-setosa
# 7  5.0          3.4         1.5          0.2         Iris-setosa
# 8  4.4          2.9         1.4          0.2         Iris-setosa
# 9  4.9          3.1         1.5          0.1         Iris-setosa
# 10 5.4          3.7         1.5          0.2         Iris-setosa
# 11 4.8          3.4         1.6          0.2         Iris-setosa
# 12 4.8          3.0         1.4          0.1         Iris-setosa
# 13 4.3          3.0         1.1          0.1         Iris-setosa
# 14 5.8          4.0         1.2          0.2         Iris-setosa
# ...

# %% [markdown]
# # Playing with some Spotify Datasets
#
# https://www.kaggle.com/code/ishank201202/spotify-music-recommendation-system/input?select=dataset.csv

# %%
tracks <- read_csv("data/dataset.csv")

names(tracks)
# Col Selection
tracks_gender_and_names <- tracks %>% select(c("track_genre", "artists"))
tracks_gender_and_names
# Out:
# New names:
# • `` -> `...1`
# Rows: 114000 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): track_id, artists, album_name, track_name, track_genre
# dbl (15): ...1, popularity, duration_ms, danceability, energy, key, loudness...
# lgl  (1): explicit
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#  [1] "...1"             "track_id"         "artists"          "album_name"
#  [5] "track_name"       "popularity"       "duration_ms"      "explicit"
#  [9] "danceability"     "energy"           "key"              "loudness"
# [13] "mode"             "speechiness"      "acousticness"     "instrumentalness"
# [17] "liveness"         "valence"          "tempo"            "time_signature"
# [21] "track_genre"
#        track_genre artists
# 1      acoustic    Gen Hoshino
# 2      acoustic    Ben Woodward
# ...

# %%
# Similar but removing a col
track_without_duration <- tracks %>% select(-"track_id")
track_without_duration
# Out:
#        ...1   artists
# 1       0     Gen Hoshino
# 2       1     Ben Woodward
# 3       2     Ingrid Michaelson;ZAYN
# 4       3     Kina Grannis
# 5       4     Chord Overstreet
# 6       5     Tyrone Wells
# 7       6     A Great Big World;Christina Aguilera
# 8       7     Jason Mraz
# 9       8     Jason Mraz;Colbie Caillat
# 10      9     Ross Copperman
# 11     10     Zack Tabudlo
# 12     11     Jason Mraz
# 13     12     Dan Berk
# 14     13     Anna Hamilton
# 15     14     Chord Overstreet;Deepend
# 16     15     Landon Pigg
# 17     16     Andrew Foy;Renee Foy
# 18     17     Andrew Foy;Renee Foy
# 19     18     Jason Mraz;Colbie Caillat
# 20     19     Boyce Avenue;Bea Miller
# 21     20     Jason Mraz
# 22     21     Boyce Avenue;Jennel Garcia
# 23     22     A Great Big World;Christina Aguilera
# 24     23     Jason Mraz
# 25     24     Jason Mraz
# 26     25     Jason Mraz
# 27     26     Jason Mraz
# 28     27     Jason Mraz
# 29     28     Jason Mraz
# ...
