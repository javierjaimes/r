# %%
# %load_ext rpy2.ipython

# %%
import pandas as pd

# %%
# Out:
# <rpy2.robjects.vectors.BoolVector object at 0x124dcd480> [RTYPES.LGLSXP]
# R classes: ('logical',)
# [       1]

# %%
# %R require(ggplot2)

# passing data from Python to R
df = pd.DataFrame({'Alphabet': ['a', 'b', 'c', 'd','e', 'f', 'g', 'h','i'],
                   'A': [4, 3, 5, 2, 1, 7, 7, 5, 9],
                   'B': [0, 4, 3, 6, 7, 10,11, 9, 13],
                   'C': [1, 2, 3, 1, 2, 3, 1, 2, 3]})

# %R -i df
# Plot the DataFrame df
ggplot(data=df) + geom_point(aes(x=A, y=B, color=C))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       9 get_ipython().run_line_magic('R', '-i df')
#      10 # Plot the DataFrame df
# ---> 11 ggplot(data=df) + geom_point(aes(x=A, y=B, color=C))
#
# NameError: name 'ggplot' is not defined

# %%
# %%R
# ggplot(data=df) + geom_point(aes(x=A, y=B, color=C))
