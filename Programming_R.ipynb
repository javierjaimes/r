# %% [markdown]
# # Iteraciones & Condicionales

# %%
library(readr)

iris <- read_csv("datasets/iris_data/iris.data")
names(iris) <- c("Sepal.Length", "Sepal.Width", "Petal.Length", "Petal.Width", "Class")
# Out:
# Rows: 149 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): Iris-setosa
# dbl (4): 5.1, 3.5, 1.4, 0.2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
promedio <- vector()

for (i in iris) {

}
# Out:
# Rows: 149 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): Iris-setosa
# dbl (4): 5.1, 3.5, 1.4, 0.2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## Condicionales

# %%
flores <- iris
flores$Sepal.Length_mid <- flores$Sepal.Length/1.5

flores
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Class
# 1   4.9          3.0         1.4          0.2         Iris-setosa
# 2   4.7          3.2         1.3          0.2         Iris-setosa
# 3   4.6          3.1         1.5          0.2         Iris-setosa
# 4   5.0          3.6         1.4          0.2         Iris-setosa
# 5   5.4          3.9         1.7          0.4         Iris-setosa
# 6   4.6          3.4         1.4          0.3         Iris-setosa
# 7   5.0          3.4         1.5          0.2         Iris-setosa
# 8   4.4          2.9         1.4          0.2         Iris-setosa
# 9   4.9          3.1         1.5          0.1         Iris-setosa
# 10  5.4          3.7         1.5          0.2         Iris-setosa
# 11  4.8          3.4         1.6          0.2         Iris-setosa
# 12  4.8          3.0         1.4          0.1         Iris-setosa
# 13  4.3          3.0         1.1          0.1         Iris-setosa
# ...

# %%
flores$type <- ifelse(flores$Sepal.Length_mid >= flores$Sepal.Width, "Type1", "Type2")

flores
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Class
# 1   4.9          3.0         1.4          0.2         Iris-setosa
# 2   4.7          3.2         1.3          0.2         Iris-setosa
# 3   4.6          3.1         1.5          0.2         Iris-setosa
# 4   5.0          3.6         1.4          0.2         Iris-setosa
# 5   5.4          3.9         1.7          0.4         Iris-setosa
# 6   4.6          3.4         1.4          0.3         Iris-setosa
# 7   5.0          3.4         1.5          0.2         Iris-setosa
# 8   4.4          2.9         1.4          0.2         Iris-setosa
# 9   4.9          3.1         1.5          0.1         Iris-setosa
# 10  5.4          3.7         1.5          0.2         Iris-setosa
# 11  4.8          3.4         1.6          0.2         Iris-setosa
# 12  4.8          3.0         1.4          0.1         Iris-setosa
# 13  4.3          3.0         1.1          0.1         Iris-setosa
# ...

# %% [markdown]
# Funciones

# %%
potencia <- function(x, y) {
    resultado <- x^y
    print(paste(x, "elevado a la", y, "es", resultado))
}

potencia(x = 8, y = 2)
# Out:
# [1] "8 elevado a la 2 es 64"

# %% [markdown]
# Graficos
#
# - Boxplot
# - Histograma
# - Diagrama de dispersion
# - Diagrama de violin
